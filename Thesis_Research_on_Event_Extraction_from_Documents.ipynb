# %% [markdown]
# <a href="https://colab.research.google.com/github/idrissdjio/3D-Brain-Tumor-Segmentation-with-Transformers-Architecture/blob/main/Thesis_Research_on_Event_Extraction_from_Documents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#let's clone the repository
# !git clone https://github.com/TencentYoutuResearch/EventExtraction-RAAT.git
# Out:
# Cloning into 'EventExtraction-RAAT'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 9), reused 39 (delta 5), pack-reused 0
# Unpacking objects: 100% (43/43), 27.96 MiB | 11.17 MiB/s, done.

# %%
# !ls
# Out:
# EventExtraction-RAAT  sample_data

# %%
#Here we move into the main repository
# !pwd
# Out:
# /content

# %%
cd EventExtraction-RAAT/
# Out:
# /content/EventExtraction-RAAT

# %%
#Let's install all the dependencies
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.8/748.8 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 KB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.0/769.0 KB 67.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 100.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 72.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 112.2 MB/s eta 0:00:00
# ...

# %%
#here we move to the Data directory and unzip the data file
#We later on move the data into the /data folder
# !ls
# Out:
# Data  dre      pictures   requirements.txt  scripts
# dee   LICENSE  README.md  run_dee_task.py

# %%
cd Data
# Out:
# /content/EventExtraction-RAAT/Data

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: Data/
#   inflating: Data/label_map.json
#   inflating: Data/test.json
#   inflating: Data/dev.json
#   inflating: Data/train.json

# %%
# !ls
# Out:
# data.zip  dev.json  label_map.json  test.json  train.json

# %%
cd ..
# Out:
# /content/EventExtraction-RAAT

# %%
# !ls
# Out:
# Data  dre      pictures   requirements.txt  scripts
# dee   LICENSE  README.md  run_dee_task.py

# %%
# !bash scripts/train_multi.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Rank 0 Iteration:   4% 1095/25606 [14:44<4:53:29,  1.39it/s]
# Rank 0 Iteration:   4% 1096/25606 [14:45<4:56:18,  1.38it/s]
# Rank 0 Iteration:   4% 1097/25606 [14:46<4:57:22,  1.37it/s]
# Rank 0 Iteration:   4% 1098/25606 [14:47<5:11:39,  1.31it/s]
# Rank 0 Iteration:   4% 1099/25606 [14:48<5:24:19,  1.26it/s]
# Rank 0 Iteration:   4% 1100/25606 [14:49<5:57:48,  1.14it/s]
# Rank 0 Iteration:   4% 1101/25606 [14:50<5:57:49,  1.14it/s]
# Rank 0 Iteration:   4% 1102/25606 [14:50<5:32:41,  1.23it/s]
# Rank 0 Iteration:   4% 1103/25606 [14:51<5:24:12,  1.26it/s]
# Rank 0 Iteration:   4% 1104/25606 [14:52<5:26:52,  1.25it/s]
# Rank 0 Iteration:   4% 1105/25606 [14:53<5:16:05,  1.29it/s]
# Rank 0 Iteration:   4% 1106/25606 [14:53<5:07:43,  1.33it/s]
# Rank 0 Iteration:   4% 1107/25606 [14:54<4:59:38,  1.36it/s]
# Rank 0 Iteration:   4% 1108/25606 [14:56<7:12:45,  1.06s/it]
# Rank 0 Iteration:   4% 1109/25606 [14:56<6:27:40,  1.05it/s]
# ...

# %%
# !echo "# Event-Extraction-from-Documents-based-on-the-RAAT" >> README.md

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git add README.md

# %%
# !git commit -m "first commit"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@340e8aba263a.(none)')

# %%
# !git config --global user.email djiofackidriss@gmail.com

# %%
# !git config --global user.name idrissdjio

# %%
# !!git commit -m "first commit"
# Out:
# ['[master (root-commit) 6512d99] first commit',
#  ' 1 file changed, 1 insertion(+)',
#  ' create mode 100644 README.md']

# %%
# !git add .

# %%
# !git commit -m "Added all"
# Out:
# [master 03018e7] Added all
#  19 files changed, 50872 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.02.17/19.28.43.652967.log
#  create mode 100644 .config/logs/2023.02.17/19.29.10.296491.log
#  create mode 100644 .config/logs/2023.02.17/19.29.36.544352.log
#  create mode 100644 .config/logs/2023.02.17/19.29.44.925165.log
#  create mode 100644 .config/logs/2023.02.17/19.30.12.368896.log
#  create mode 100644 .config/logs/2023.02.17/19.30.13.219227.log
#  create mode 100755 sample_data/README.md
#  create mode 100755 sample_data/anscombe.json
#  create mode 100644 sample_data/california_housing_test.csv
# ...
